# %%
from ultralytics import YOLO

# %%
import cv2

# %%
# import yaml
# data = {
#     'train': os.getcwd()+'\\dataset\\Custom Workflow 2 Object Detection.v1i.yolov8-obb\\train\\images',
#     'valid': os.getcwd()+'\\dataset\\Custom Workflow 2 Object Detection.v1i.yolov8-obb\\valid\\images',
#     'nc': 1,  # number of classes
#     'names': ['gun']  #  class names
# }

# # Save to dataset.yaml
# with open('dataset\\data.yaml', 'w') as file:
#     yaml.dump(data, file, default_flow_style=False)

# print("dataset.yaml file created successfully!")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Amir Sohail\\Downloads\\fyp'

# %%
import cv2
from ultralytics import YOLO
model=YOLO('best.pt')
result = model('dataset/assault rifle in hand_images/assault rifle in hand_14.jpg' , show=True)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 4
#       2 from ultralytics import YOLO
#       3 model=YOLO('best.pt')
# ----> 4 result = model('dataset/assault rifle in hand_images/assault rifle in hand_14.jpg' , show=True)
#       5 cv2.waitKey(0)
#       6 cv2.destroyAllWindows()
#
# File /opt/miniconda3/lib/python3.12/site-packages/ultralytics/engine/model.py:182, in Model.__call__(self, source, stream, **kwargs)
#     153 def __call__(
#     154     self,
#     155     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     156     stream: bool = False,
#     157     **kwargs: Any,
#     158 ) -> list:
#     159     """
#     160     Alias for the predict method, enabling the model instance to be callable for predictions.
#     161
#    (...)
#     180         ...     print(f"Detected {len(r)} objects in image")
# ...

# %%
cap = cv2.VideoCapture(0)  # open default camera

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # run yolo model on each frame
    results = model(frame)

    # display output
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            label = f"{model.names[int(box.cls[0])]} {box.conf[0]:.2f}"
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    cv2.imshow("Real Time/Live Weapon Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 285.3ms
# Speed: 6.2ms preprocess, 285.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 242.2ms
# Speed: 8.2ms preprocess, 242.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 211.6ms
# Speed: 4.9ms preprocess, 211.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 198.9ms
# Speed: 4.9ms preprocess, 198.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.3ms
# Speed: 4.7ms preprocess, 207.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 211.7ms
# Speed: 4.5ms preprocess, 211.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 202.3ms
# Speed: 4.8ms preprocess, 202.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/saadamir/Documents/fyp'

# %%
pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anaconda-anon-usage       0.5.0
# annotated-types           0.6.0
# anyio                     4.6.2
# appnope                   0.1.3
# archspec                  0.2.3
# argon2-cffi               21.3.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# attrs                     24.3.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# boltons                   24.1.0
# Brotli                    1.0.9
# certifi                   2025.1.31
# cffi                      1.17.1
# charset-normalizer        3.3.2
# comm                      0.2.1
# conda                     25.3.1
# conda-anaconda-telemetry  0.1.2
# conda-anaconda-tos        0.1.2
# conda-content-trust       0.2.0
# conda-libmamba-solver     25.1.1
# conda-package-handling    2.4.0
# ...

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Mar 27 00:20:35 2025

@author: Saad Amir Sohail
"""

import tkinter as tk
from tkinter import filedialog, Label, Button, Canvas
from PIL import Image, ImageTk
# import cv2
# import torch
import os
from ultralytics import YOLO

# loading model
model = YOLO(os.getcwd()+'/best.pt')

def select_file():
    file_path = filedialog.askopenfilename(filetypes=[('Image/Video Files', '*.jpg;*.jpeg;*.png;*.mp4')])
    if file_path:
        file_label.config(text=f"Selected: {file_path}")
        process_file(file_path)

def process_file(file_path):
    img = Image.open(file_path) if file_path.endswith(('jpg', 'png', 'jpeg')) else None
    
    if img:
        img.thumbnail((400, 400))
        img = ImageTk.PhotoImage(img)
        canvas.create_image(200, 200, anchor=tk.CENTER, image=img)
        canvas.image = img  # Keep reference to avoid garbage collection
    
    # performing detection
    results = model(file_path)
    results.show()  # show detection result (for testing)
    results.save(save_dir="detections/")  # Save detection results

    result_label.config(text="Detection Complete! Check 'detections/' folder.")

# creating UI window
root = tk.Tk()
root.title("Smart Behavior and Weapon Detection System")
root.geometry("500x600")

Label(root, text="Smart Behavior and Weapon Detection System", font=("Arial", 16)).pack(pady=10)
Button(root, text="Select Image/Video", command=select_file).pack(pady=5)
Button(root, text="Live Detection").pack(pady=5)
Button(root, text="Exit").pack(pady=5)
file_label = Label(root, text="No file selected", fg="red")
file_label.pack()

canvas = Canvas(root, width=400, height=400, bg="gray")
canvas.pack(pady=10)

result_label = Label(root, text="", fg="green")
result_label.pack()

root.mainloop()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/opt/miniconda3/lib/python3.12/runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/opt/miniconda3/lib/python3.12/runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "/opt/miniconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/miniconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
# ...
